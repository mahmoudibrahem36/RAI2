# %%
# !pip install Graphviz

# %%
from graphviz import Digraph

dot = Digraph()

# Define nodes
dot.node('Model_Definition', '1. Model Definition (build_model)', shape='ellipse')
dot.node('Regularization', '2. Regularization (apply_regularization)', shape='ellipse')
dot.node('Training', '3. Training (train_model)', shape='ellipse')
dot.node('Evaluation', '4. Evaluation (evaluate_model)', shape='ellipse')
dot.node('Usage', '5. Usage', shape='ellipse')

# Define sub-nodes for Model Definition
dot.node('Load_BERT', 'Load the pre-trained BERT model \'bert-base-uncased\'')
dot.node('Define_Inputs', 'Define model inputs: input_ids, attention_mask')
dot.node('Pass_Through_BERT', 'Pass inputs through the BERT model')
dot.node('Extract_CLS', 'Extract the CLS token')
dot.node('Define_Output', 'Define the output layer')
dot.node('Create_Model', 'Create and Compile the model')
dot.node('Apply_Regularization', 'Apply L2 regularization (optional)')

# Define sub-nodes for Regularization
dot.node('Check_Layers', 'Iterate through all layers')
dot.node('Set_Regularizer', 'Set kernel regularizer to L2')

# Define sub-nodes for Training
dot.node('Train_Model', 'Train the model on the training dataset')

# Define sub-nodes for Evaluation
dot.node('Make_Predictions', 'Make predictions on the test dataset')
dot.node('Convert_To_Binary', 'Convert predictions to binary labels')
dot.node('Gather_True_Labels', 'Gather true labels from the test dataset')
dot.node('Generate_Report', 'Generate classification report')
dot.node('Calculate_Metrics', 'Calculate evaluation metrics')
dot.node('Calculate_CM', 'Calculate confusion matrix')

# Define sub-nodes for Usage
dot.node('Load_Data', 'Load training and test data')
dot.node('Regulatory_Compliance', 'Apply regulatory compliance checks')
dot.node('Load_Tokenizer', 'Load the tokenizer')
dot.node('Preprocess_Data', 'Preprocess data')
dot.node('Build_Model', 'Build the model')
dot.node('Train_Model_Usage', 'Train the model')
dot.node('Evaluate_Model', 'Evaluate the model')

# Define edges
dot.edge('Model_Definition', 'Load_BERT')
dot.edge('Load_BERT', 'Define_Inputs')
dot.edge('Define_Inputs', 'Pass_Through_BERT')
dot.edge('Pass_Through_BERT', 'Extract_CLS')
dot.edge('Extract_CLS', 'Define_Output')
dot.edge('Define_Output', 'Create_Model')
dot.edge('Create_Model', 'Apply_Regularization')
dot.edge('Regularization', 'Check_Layers')
dot.edge('Check_Layers', 'Set_Regularizer')
dot.edge('Training', 'Train_Model')
dot.edge('Evaluation', 'Make_Predictions')
dot.edge('Make_Predictions', 'Convert_To_Binary')
dot.edge('Convert_To_Binary', 'Gather_True_Labels')
dot.edge('Gather_True_Labels', 'Generate_Report')
dot.edge('Generate_Report', 'Calculate_Metrics')
dot.edge('Calculate_Metrics', 'Calculate_CM')
dot.edge('Usage', 'Load_Data')
dot.edge('Load_Data', 'Regulatory_Compliance')
dot.edge('Regulatory_Compliance', 'Load_Tokenizer')
dot.edge('Load_Tokenizer', 'Preprocess_Data')
dot.edge('Preprocess_Data', 'Build_Model')
dot.edge('Build_Model', 'Apply_Regularization')
dot.edge('Apply_Regularization', 'Train_Model_Usage')
dot.edge('Train_Model_Usage', 'Evaluate_Model')

# Render and display
dot.render('bert_text_classification', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph()

# Define nodes
dot.node('Input_Layer', 'Input Layer', shape='ellipse')
dot.node('Embeddings', 'BERT Embeddings', shape='ellipse')
dot.node('Encoder_Layers', 'BERT Encoder Layers', shape='ellipse')
dot.node('Pooling', 'Pooling Layer (CLS Token)', shape='ellipse')
dot.node('Dense_Layer', 'Dense Layer (Output)', shape='ellipse')
dot.node('Output_Layer', 'Output Layer (Sigmoid)', shape='ellipse')

# Define edges
dot.edge('Input_Layer', 'Embeddings')
dot.edge('Embeddings', 'Encoder_Layers')
dot.edge('Encoder_Layers', 'Pooling')
dot.edge('Pooling', 'Dense_Layer')
dot.edge('Dense_Layer', 'Output_Layer')

# Render and display
dot.render('bert_model_structure', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph()

# Define nodes
dot.node('Input_Tokens', 'Input Tokens', shape='ellipse')
dot.node('Token_Embeddings', 'Token Embeddings', shape='ellipse')
dot.node('Positional_Encodings', 'Positional Encodings', shape='ellipse')
dot.node('Embeddings', 'Sum of Embeddings + Encodings', shape='ellipse')
dot.node('Attention_Mechanism', 'Multi-Head Attention', shape='ellipse')
dot.node('Add_And_Norm1', 'Add & Norm (Residual + Layer Norm)', shape='ellipse')
dot.node('Feed_Forward', 'Feed-Forward Network', shape='ellipse')
dot.node('Add_And_Norm2', 'Add & Norm (Residual + Layer Norm)', shape='ellipse')
dot.node('Output_Embeddings', 'Output Embeddings', shape='ellipse')

# Define edges
dot.edge('Input_Tokens', 'Token_Embeddings')
dot.edge('Input_Tokens', 'Positional_Encodings')
dot.edge('Token_Embeddings', 'Embeddings')
dot.edge('Positional_Encodings', 'Embeddings')
dot.edge('Embeddings', 'Attention_Mechanism')
dot.edge('Attention_Mechanism', 'Add_And_Norm1')
dot.edge('Add_And_Norm1', 'Feed_Forward')
dot.edge('Feed_Forward', 'Add_And_Norm2')
dot.edge('Add_And_Norm2', 'Output_Embeddings')

# Render and display
dot.render('bert_inner_structure', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph()

# Define nodes with colors and shapes
dot.node('Input_Tokens', 'Input Tokens\n(Tokenized Text)', shape='ellipse', fillcolor='#F8F8F8', style='filled')
dot.node('Token_Embeddings', 'Token Embeddings', shape='box', fillcolor='#E0E0E0', style='filled')
dot.node('Positional_Encodings', 'Positional Encodings', shape='box', fillcolor='#E0E0E0', style='filled')
dot.node('Embeddings', 'Sum of Embeddings + Encodings', shape='box', fillcolor='#D0D0D0', style='filled')
dot.node('Attention_Mechanism', 'Multi-Head Attention\n(Attention Scores)', shape='box', fillcolor='#C0C0C0', style='filled')
dot.node('Add_And_Norm1', 'Add & Norm\n(Residual + Layer Norm)', shape='box', fillcolor='#B0B0B0', style='filled')
dot.node('Feed_Forward', 'Feed-Forward Network\n(Dense Layers)', shape='box', fillcolor='#A0A0A0', style='filled')
dot.node('Add_And_Norm2', 'Add & Norm\n(Residual + Layer Norm)', shape='box', fillcolor='#B0B0B0', style='filled')
dot.node('Output_Embeddings', 'Output Embeddings', shape='ellipse', fillcolor='#F8F8F8', style='filled')

# Define edges with styles
dot.edge('Input_Tokens', 'Token_Embeddings', label="Embeddings Lookup", color="#777777")
dot.edge('Input_Tokens', 'Positional_Encodings', label="Add Position", color="#777777")
dot.edge('Token_Embeddings', 'Embeddings', label="Combine Embeddings", color="#777777")
dot.edge('Positional_Encodings', 'Embeddings', label="Combine Encodings", color="#777777")
dot.edge('Embeddings', 'Attention_Mechanism', label="Attention Input", color="#777777")
dot.edge('Attention_Mechanism', 'Add_And_Norm1', label="Attention Output", color="#777777")
dot.edge('Add_And_Norm1', 'Feed_Forward', label="Normalized Output", color="#777777")
dot.edge('Feed_Forward', 'Add_And_Norm2', label="Feed-Forward Output", color="#777777")
dot.edge('Add_And_Norm2', 'Output_Embeddings', label="Final Output", color="#777777")

# Add a title
dot.attr(label="Detailed Inner Structure of BERT Model", labelloc="t", fontsize="14", fontcolor="#000000")

# Render and display
dot.render('bert_inner_structure', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph()

# Define nodes with detailed descriptions
dot.node('Input_Layers', 'Input Layers\n- input_ids (shape=128,)\n- attention_mask (shape=128,)', shape='ellipse', fillcolor='#F8F8F8', style='filled')
dot.node('BERT_Output', 'BERT Output\n- Hidden States (shape=N, T, D)\n- N: Batch Size\n- T: Sequence Length\n- D: Hidden Size (768)', shape='box', fillcolor='#E0E0E0', style='filled')
dot.node('CLS_Token', 'CLS Token\n- Embedding of [CLS] Token\n- Shape (N, D)', shape='box', fillcolor='#D0D0D0', style='filled')
dot.node('Dense1', 'Dense Layer 1\n- ReLU(W1 . CLS_Token + b1)\n- Shape (N, D)', shape='box', fillcolor='#C0C0C0', style='filled')
dot.node('Dropout', 'Dropout\n- Dropout(Dense1, rate=0.3)', shape='box', fillcolor='#B0B0B0', style='filled')
dot.node('Dense2', 'Dense Layer 2\n- Sigmoid(W2 . Dropout + b2)', shape='box', fillcolor='#A0A0A0', style='filled')
dot.node('Output', 'Output\n- Binary Classification\n- Sigmoid Activation', shape='ellipse', fillcolor='#F8F8F8', style='filled')
dot.node('Compilation', 'Model Compilation\n- Adam Optimizer\n- Learning Rate: 2e-5\n- Loss Function: Binary Cross-Entropy\n- Metrics: Accuracy, Precision, Recall, AUC', shape='box', fillcolor='#E8E8E8', style='filled')

# Define edges with labels and styles
dot.edge('Input_Layers', 'BERT_Output', label="Input to BERT", color="#777777")
dot.edge('BERT_Output', 'CLS_Token', label="Extract [CLS] Token", color="#777777")
dot.edge('CLS_Token', 'Dense1', label="Input to Dense Layer 1", color="#777777")
dot.edge('Dense1', 'Dropout', label="Apply Dropout", color="#777777")
dot.edge('Dropout', 'Dense2', label="Input to Dense Layer 2", color="#777777")
dot.edge('Dense2', 'Output', label="Generate Output", color="#777777")
dot.edge('Output', 'Compilation', label="Compiled Model", color="#777777")

# Add a title
dot.attr(label="Detailed Inner Structure of BERT Model for Text Classification", labelloc="t", fontsize="14", fontcolor="#000000")

# Render and display
dot.render('bert_model_inner_structure', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph()

# Define nodes
dot.node('Input_Layers', 'Input Layers\n- input_ids (shape=128,)\n- attention_mask (shape=128,)', shape='ellipse', fillcolor='#F0F0F0', style='filled')
dot.node('BERT_Output', 'BERT Output\n- Hidden States (shape=N, T, D)\n- N: Batch Size\n- T: Sequence Length\n- D: Hidden Size (768)', shape='box', fillcolor='#E0E0E0', style='filled')
dot.node('CLS_Token', 'CLS Token\n- Embedding of [CLS] Token\n- Shape (N, D)', shape='box', fillcolor='#D0D0D0', style='filled')
dot.node('Dense1', 'Dense Layer 1\n- ReLU(W1 . CLS_Token + b1)\n- Shape (N, D)', shape='box', fillcolor='#C0C0C0', style='filled')
dot.node('Dropout', 'Dropout\n- Dropout(Dense1, rate=0.3)', shape='box', fillcolor='#B0B0B0', style='filled')
dot.node('Dense2', 'Dense Layer 2\n- Sigmoid(W2 . Dropout + b2)', shape='box', fillcolor='#A0A0A0', style='filled')
dot.node('Output', 'Output\n- Binary Classification\n- Sigmoid Activation', shape='ellipse', fillcolor='#F0F0F0', style='filled')
dot.node('Compilation', 'Model Compilation\n- Adam Optimizer\n- Learning Rate: 2e-5\n- Loss: Binary Cross-Entropy\n- Metrics: Accuracy, Precision, Recall, AUC', shape='box', fillcolor='#E8E8E8', style='filled')

# Define edges
dot.edge('Input_Layers', 'BERT_Output', label="Input to BERT")
dot.edge('BERT_Output', 'CLS_Token', label="Extract [CLS] Token")
dot.edge('CLS_Token', 'Dense1', label="Input to Dense Layer 1")
dot.edge('Dense1', 'Dropout', label="Apply Dropout")
dot.edge('Dropout', 'Dense2', label="Input to Dense Layer 2")
dot.edge('Dense2', 'Output', label="Generate Output")
dot.edge('Output', 'Compilation', label="Compiled Model")

# Add a title
dot.attr(label="Detailed Inner Structure of BERT Model for Text Classification", labelloc="t", fontsize="14", fontcolor="#000000")

# Render and display
dot.render('bert_model_inner_structure', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph(graph_attr={'rankdir': 'LR'})  # Set direction to left-to-right

# Define nodes
dot.node('Input_Layers', 'Input Layers\n- input_ids (shape=128,)\n- attention_mask (shape=128,)', shape='ellipse', fillcolor='#F0F0F0', style='filled')
dot.node('BERT_Output', 'BERT Output\n- Hidden States (shape=N, T, D)\n- N: Batch Size\n- T: Sequence Length\n- D: Hidden Size (768)', shape='box', fillcolor='#E0E0E0', style='filled')
dot.node('CLS_Token', 'CLS Token\n- Embedding of [CLS] Token\n- Shape (N, D)', shape='box', fillcolor='#D0D0D0', style='filled')
dot.node('Dense1', 'Dense Layer 1\n- ReLU(W1 . CLS_Token + b1)\n- Shape (N, D)', shape='box', fillcolor='#C0C0C0', style='filled')
dot.node('Dropout', 'Dropout\n- Dropout(Dense1, rate=0.3)', shape='box', fillcolor='#B0B0B0', style='filled')
dot.node('Dense2', 'Dense Layer 2\n- Sigmoid(W2 . Dropout + b2)', shape='box', fillcolor='#A0A0A0', style='filled')
dot.node('Output', 'Output\n- Binary Classification\n- Sigmoid Activation', shape='ellipse', fillcolor='#F0F0F0', style='filled')
dot.node('Compilation', 'Model Compilation\n- Adam Optimizer\n- Learning Rate: 2e-5\n- Loss: Binary Cross-Entropy\n- Metrics: Accuracy, Precision, Recall, AUC', shape='box', fillcolor='#E8E8E8', style='filled')

# Define edges
dot.edge('Input_Layers', 'BERT_Output', label="Input to BERT")
dot.edge('BERT_Output', 'CLS_Token', label="Extract [CLS] Token")
dot.edge('CLS_Token', 'Dense1', label="Input to Dense Layer 1")
dot.edge('Dense1', 'Dropout', label="Apply Dropout")
dot.edge('Dropout', 'Dense2', label="Input to Dense Layer 2")
dot.edge('Dense2', 'Output', label="Generate Output")
dot.edge('Output', 'Compilation', label="Compiled Model")

# Add a title
dot.attr(label="Detailed Inner Structure of BERT Model for Text Classification", labelloc="t", fontsize="14", fontcolor="#000000")

# Render and display
dot.render('bert_model_inner_structure', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph(graph_attr={'rankdir': 'LR'})  # Set direction to left-to-right

# Define nodes
dot.node('Load_Data', 'Load Data\n- train_data, test_data = load_data()', shape='ellipse', fillcolor='#F0F0F0', style='filled')
dot.node('Preprocess_Data', 'Preprocess Data\n- train_dataset, test_dataset = preprocess_data(train_data, test_data)', shape='ellipse', fillcolor='#E0E0E0', style='filled')
dot.node('Tokenizer', 'Tokenizer\n- tokenizer = BertTokenizer.from_pretrained()', shape='box', fillcolor='#D0D0D0', style='filled')
dot.node('Build_Model', 'Build Model\n- model = build_model()', shape='box', fillcolor='#C0C0C0', style='filled')
dot.node('Apply_Regularization', 'Apply Regularization\n- model = apply_regularization(model)', shape='box', fillcolor='#B0B0B0', style='filled')
dot.node('Train_Model', 'Train Model\n- history = train_model(model, train_dataset, test_dataset)', shape='box', fillcolor='#A0A0A0', style='filled')
dot.node('Evaluate_Model', 'Evaluate Model\n- metrics = evaluate_model(model, test_dataset)', shape='ellipse', fillcolor='#F0F0F0', style='filled')

# Define edges
dot.edge('Load_Data', 'Preprocess_Data', label="Data Loading")
dot.edge('Preprocess_Data', 'Tokenizer', label="Data Tokenization")
dot.edge('Tokenizer', 'Build_Model', label="Tokenizer to Model")
dot.edge('Build_Model', 'Apply_Regularization', label="Model Building")
dot.edge('Apply_Regularization', 'Train_Model', label="Apply Regularization")
dot.edge('Train_Model', 'Evaluate_Model', label="Model Training and Evaluation")

# Add a title
dot.attr(label="End-to-End BERT-based Text Classification Model Architecture", labelloc="t", fontsize="14", fontcolor="#000000")

# Render and display
dot.render('bert_model_architecture', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph(graph_attr={'rankdir': 'LR'})  # Set direction to left-to-right

# Define nodes
dot.node('Input_Layers', 'Input Layers\n- input_ids (shape=128,)\n- attention_mask (shape=128,)', shape='ellipse', fillcolor='#F0F0F0', style='filled')
dot.node('BERT_Output', 'BERT Output\n- Hidden States (shape=N, T, D)\n- N: Batch Size\n- T: Sequence Length\n- D: Hidden Size (768)', shape='box', fillcolor='#E0E0E0', style='filled')
dot.node('CLS_Token', 'CLS Token\n- Embedding of [CLS] Token\n- Shape (N, D)', shape='box', fillcolor='#D0D0D0', style='filled')
dot.node('Dense1', 'Dense Layer 1\n- ReLU(W1 . CLS_Token + b1)\n- Shape (N, D)', shape='box', fillcolor='#C0C0C0', style='filled')
dot.node('Dropout', 'Dropout\n- Dropout(Dense1, rate=0.3)', shape='box', fillcolor='#B0B0B0', style='filled')
dot.node('Dense2', 'Dense Layer 2\n- Sigmoid(W2 . Dropout + b2)', shape='box', fillcolor='#A0A0A0', style='filled')
dot.node('Output', 'Output\n- Binary Classification\n- Sigmoid Activation', shape='ellipse', fillcolor='#F0F0F0', style='filled')

# Define edges
dot.edge('Input_Layers', 'BERT_Output', label="Input to BERT")
dot.edge('BERT_Output', 'CLS_Token', label="Extract [CLS] Token")
dot.edge('CLS_Token', 'Dense1', label="Input to Dense Layer 1")
dot.edge('Dense1', 'Dropout', label="Apply Dropout")
dot.edge('Dropout', 'Dense2', label="Input to Dense Layer 2")
dot.edge('Dense2', 'Output', label="Generate Output")

# Add a title
dot.attr(label="Detailed Inner Structure of BERT Model for Text Classification", labelloc="t", fontsize="14", fontcolor="#000000")

# Render and display
dot.render('bert_model_inner_structure_horizontal', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph()

# Define nodes with concise descriptions
dot.node('Input_Layers', 'Input Layers\n- input_ids (128,)\n- attention_mask (128,)', shape='ellipse', fillcolor='#E8F4F8', style='filled')
dot.node('BERT_Output', 'BERT Output\n- Hidden States (N, T, D)\n- D: 768', shape='box', fillcolor='#C7D7E0', style='filled')
dot.node('CLS_Token', 'CLS Token\n- Shape (N, D)', shape='box', fillcolor='#B0C5D2', style='filled')
dot.node('Dense1', 'Dense Layer 1\n- ReLU Activation', shape='box', fillcolor='#9AB1C0', style='filled')
dot.node('Dropout', 'Dropout\n- Rate: 0.3', shape='box', fillcolor='#8A9FAD', style='filled')
dot.node('Dense2', 'Dense Layer 2\n- Sigmoid Activation', shape='box', fillcolor='#7C8C9A', style='filled')
dot.node('Output', 'Output\n- Binary Classification', shape='ellipse', fillcolor='#E8F4F8', style='filled')
dot.node('Compilation', 'Model Compilation\n- Adam\n- Learning Rate: 2e-5\n- Binary Cross-Entropy\n- Metrics: Accuracy, Precision, Recall, AUC', shape='box', fillcolor='#D6E2E5', style='filled')

# Define edges with clear labels
dot.edge('Input_Layers', 'BERT_Output', label="Feed into BERT")
dot.edge('BERT_Output', 'CLS_Token', label="Extract [CLS]")
dot.edge('CLS_Token', 'Dense1', label="Input to Dense 1")
dot.edge('Dense1', 'Dropout', label="Apply Dropout")
dot.edge('Dropout', 'Dense2', label="Input to Dense 2")
dot.edge('Dense2', 'Output', label="Generate Output")
dot.edge('Output', 'Compilation', label="Compile Model")

# Add a title
dot.attr(label="BERT Model Inner Structure for Text Classification", labelloc="t", fontsize="14", fontcolor="#000000")

# Render and display
dot.render('bert_model_inner_structure', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph(graph_attr={'rankdir': 'TB'})  # Set direction to top-to-bottom

# Define nodes
dot.node('Data_Preprocessing', '1. Data Preprocessing\n- Split Data\n- Tokenize Data', shape='ellipse', fillcolor='#F0F0F0', style='filled')
dot.node('Dataset_Creation', '2. Dataset Creation\n- Create Training and Test Datasets', shape='box', fillcolor='#E0E0E0', style='filled')
dot.node('Data_Loading', '3. Data Loading\n- Create Data Loaders', shape='box', fillcolor='#D0D0D0', style='filled')
dot.node('Model_Optimization', '4. Model Optimization\n- Initialize Optimizer\n- Calculate Total Steps\n- Initialize Scheduler\n- Initialize Loss Function', shape='box', fillcolor='#C0C0C0', style='filled')
dot.node('Model_Training', '5. Model Training\n- Train Model', shape='box', fillcolor='#B0B0B0', style='filled')
dot.node('Model_Evaluation', '6. Model Evaluation\n- Initialize Metrics\n- Evaluate Model\n- Calculate Accuracy\n- Print Metrics', shape='box', fillcolor='#A0A0A0', style='filled')
dot.node('Model_Saving', '7. Model Saving\n- Save Model', shape='ellipse', fillcolor='#F0F0F0', style='filled')
dot.node('Output', 'Output\n- Return Trained Model\n- Return Accuracy', shape='ellipse', fillcolor='#E8E8E8', style='filled')

# Define edges
dot.edge('Data_Preprocessing', 'Dataset_Creation', label="Generate Encodings")
dot.edge('Dataset_Creation', 'Data_Loading', label="Create Datasets")
dot.edge('Data_Loading', 'Model_Optimization', label="Create Data Loaders")
dot.edge('Model_Optimization', 'Model_Training', label="Initialize Optimizer and Scheduler")
dot.edge('Model_Training', 'Model_Evaluation', label="Train Model")
dot.edge('Model_Evaluation', 'Model_Saving', label="Evaluate Model")
dot.edge('Model_Saving', 'Output', label="Save and Return Model")

# Add a title
dot.attr(label="Detailed Inner Structure of BERT Model for Text Classification", labelloc="t", fontsize="14", fontcolor="#000000")

# Render and display
dot.render('bert_model_inner_structure_vertical', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph(comment='BERT Model for Text Classification', graph_attr={'rankdir': 'TB'})  # Set direction to top-to-bottom

# Define nodes
dot.node('Data_Preprocessing', '1. Data Preprocessing\n- Split Data\n- Tokenize Data', shape='box', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Dataset_Creation', '2. Dataset Creation\n- Create Training and Test Datasets', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Data_Loading', '3. Data Loading\n- Create Data Loaders', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Model_Optimization', '4. Model Optimization\n- Initialize Optimizer\n- Calculate Total Steps\n- Initialize Scheduler\n- Initialize Loss Function', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Model_Training', '5. Model Training\n- Train Model', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Model_Evaluation', '6. Model Evaluation\n- Initialize Metrics\n- Evaluate Model\n- Calculate Accuracy\n- Print Metrics', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('Model_Saving', '7. Model Saving\n- Save Model', shape='box', style='filled, rounded', fillcolor='#909090')
dot.node('Output', 'Output\n- Return Trained Model\n- Return Accuracy', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')

# Define edges
dot.edge('Data_Preprocessing', 'Dataset_Creation', label="Generate Encodings", style='solid')
dot.edge('Dataset_Creation', 'Data_Loading', label="Create Datasets", style='solid')
dot.edge('Data_Loading', 'Model_Optimization', label="Create Data Loaders", style='solid')
dot.edge('Model_Optimization', 'Model_Training', label="Initialize Optimizer and Scheduler", style='solid')
dot.edge('Model_Training', 'Model_Evaluation', label="Train Model", style='solid')
dot.edge('Model_Evaluation', 'Model_Saving', label="Evaluate Model", style='solid')
dot.edge('Model_Saving', 'Output', label="Save and Return Model", style='solid')

# Add a title
dot.attr(label="Detailed Inner Structure of BERT Model for Text Classification", labelloc="t", fontsize="16", fontcolor="#000000", fontname='Helvetica')

# Render and display
dot.render('bert_model_inner_structure_vertical', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

dot = Digraph(comment='BERT Model Inner Architecture', graph_attr={'rankdir': 'LR'})  # Set direction to left-to-right

# Define nodes
dot.node('Input_Layers', 'Input Layers\n- input_ids (shape=128,)\n- attention_mask (shape=128,)', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('BERT_Output', 'BERT Output\n- Hidden States (shape=N, T, D)\n- N: Batch Size\n- T: Sequence Length\n- D: Hidden Size (768)', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('CLS_Token', 'CLS Token\n- Embedding of [CLS] Token\n- Shape (N, D)', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Dense1', 'Dense Layer 1\n- ReLU(W1 . CLS_Token + b1)\n- Shape (N, D)', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Dropout', 'Dropout\n- Dropout(Dense1, rate=0.3)', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Dense2', 'Dense Layer 2\n- Sigmoid(W2 . Dropout + b2)', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('Output', 'Output\n- Binary Classification\n- Sigmoid Activation', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Compilation', 'Model Compilation\n- Adam Optimizer\n- Learning Rate: 2e-5\n- Loss: Binary Cross-Entropy\n- Metrics: Accuracy, Precision, Recall, AUC', shape='box', style='filled, rounded', fillcolor='#E8E8E8')

# Define edges
dot.edge('Input_Layers', 'BERT_Output', label="Input to BERT", style='solid')
dot.edge('BERT_Output', 'CLS_Token', label="Extract [CLS] Token", style='solid')
dot.edge('CLS_Token', 'Dense1', label="Input to Dense Layer 1", style='solid')
dot.edge('Dense1', 'Dropout', label="Apply Dropout", style='solid')
dot.edge('Dropout', 'Dense2', label="Input to Dense Layer 2", style='solid')
dot.edge('Dense2', 'Output', label="Generate Output", style='solid')
dot.edge('Output', 'Compilation', label="Compiled Model", style='solid')

# Add a title
dot.attr(label="Detailed Inner Structure of BERT Model for Text Classification", labelloc="t", fontsize="16", fontcolor="#000000", fontname='Helvetica')

# Render and display
dot.render('bert_model_inner_architecture', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

# Create a graph
dot = Digraph(comment='GPT Model Inner Architecture', graph_attr={'rankdir': 'TB'})  # Set direction to top-to-bottom

# Define nodes for each step
dot.node('Data_Loading', 'Data Loading and Preprocessing\n- Load dataset\n- Lowercase conversion\n- Remove special characters\n- Remove extra spaces', shape='box', style='filled, rounded', fillcolor='#F0F0F0')

dot.node('Data_Splitting', 'Data Splitting\n- Split into train and test sets\n- train_test_split()', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

dot.node('Tokenization', 'Tokenization\n- Initialize GPT-2 tokenizer\n- Tokenize train and test data', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

dot.node('Tensors', 'Convert to Tensors\n- Convert input_ids and attention_mask to tensors\n- Convert labels to tensors', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

dot.node('Dataset', 'Dataset Creation\n- Define CustomDataset class\n- Create train and test datasets', shape='box', style='filled, rounded', fillcolor='#B0B0B0')

dot.node('DataLoader', 'DataLoader\n- Create DataLoader for train and test datasets\n- Specify batch_size and shuffle', shape='box', style='filled, rounded', fillcolor='#A0A0A0')

dot.node('Model_Definition', 'Model Definition\n- Define GPTClassifier\n- Initialize GPT-2 model\n- Define forward method\n- Output layer for binary classification', shape='box', style='filled, rounded', fillcolor='#90A0A0')

dot.node('Optimization', 'Optimization\n- Initialize AdamW optimizer\n- Define scheduler\n- Define loss function', shape='box', style='filled, rounded', fillcolor='#80B0B0')

dot.node('Training', 'Model Training\n- Train the model for num_epochs\n- Calculate loss and update weights\n- Adjust learning rate with scheduler', shape='box', style='filled, rounded', fillcolor='#70C0C0')

dot.node('Evaluation', 'Model Evaluation\n- Set model to eval mode\n- Make predictions on test set\n- Calculate evaluation metrics', shape='box', style='filled, rounded', fillcolor='#60D0D0')

dot.node('Metrics', 'Metrics Calculation\n- Accuracy\n- Precision\n- Recall\n- F1 Score\n- AUC', shape='box', style='filled, rounded', fillcolor='#50E0E0')

dot.node('ROC_Plot', 'Plot ROC Curve\n- Calculate ROC curve\n- Plot with matplotlib', shape='box', style='filled, rounded', fillcolor='#40F0F0')

# Define edges between steps
dot.edge('Data_Loading', 'Data_Splitting')
dot.edge('Data_Splitting', 'Tokenization')
dot.edge('Tokenization', 'Tensors')
dot.edge('Tensors', 'Dataset')
dot.edge('Dataset', 'DataLoader')
dot.edge('DataLoader', 'Model_Definition')
dot.edge('Model_Definition', 'Optimization')
dot.edge('Optimization', 'Training')
dot.edge('Training', 'Evaluation')
dot.edge('Evaluation', 'Metrics')
dot.edge('Metrics', 'ROC_Plot')

# Add a title
dot.attr(label="Detailed Inner Structure of GPT-based Model for Text Classification", labelloc="t", fontsize="16", fontcolor="#000000", fontname='Helvetica')

# Render and display
dot.render('gpt_model_inner_architecture', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

# Create a graph
dot = Digraph(comment='GPT Model Inner Architecture', graph_attr={'rankdir': 'TB'})  # Set direction to top-to-bottom

# Define nodes for each step
dot.node('Input_Ids', 'Input IDs\n(shape=(batch_size, 128))', shape='box', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Attention_Mask', 'Attention Mask\n(shape=(batch_size, 128))', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

dot.node('GPT2_Layers', 'GPT-2 Model\n(12 transformer layers)', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

dot.node('Last_Hidden_State', 'Last Hidden State\n(shape=(batch_size, 128, n_embd))', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Pooled_Output', '[CLS] Token Output\n(shape=(batch_size, n_embd))', shape='box', style='filled, rounded', fillcolor='#B0B0B0')

dot.node('Dropout', 'Dropout Layer\n(rate=0.1)', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('FC_Layer', 'Fully Connected Layer\n(output size=2)', shape='box', style='filled, rounded', fillcolor='#90A0A0')

dot.node('Logits', 'Logits\n(shape=(batch_size, 2))', shape='box', style='filled, rounded', fillcolor='#80B0B0')

# Define edges between steps
dot.edge('Input_Ids', 'GPT2_Layers')
dot.edge('Attention_Mask', 'GPT2_Layers')
dot.edge('GPT2_Layers', 'Last_Hidden_State')
dot.edge('Last_Hidden_State', 'Pooled_Output')
dot.edge('Pooled_Output', 'Dropout')
dot.edge('Dropout', 'FC_Layer')
dot.edge('FC_Layer', 'Logits')

# Add a title
dot.attr(label="Inner Structure of GPT-based Model for Text Classification", labelloc="t", fontsize="16", fontcolor="#000000", fontname='Helvetica')

# Render and display
dot.render('gpt_model_inner_architecture_layers', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

# Create a graph
dot = Digraph(comment='LSTM Model with Embeddings and Attention Architecture', graph_attr={'rankdir': 'TB'})  # Set direction to top-to-bottom

# Define nodes for each layer in the model
dot.node('Input', 'Input Layer\n(shape=(max_sequence_length,))', shape='box', style='filled, rounded', fillcolor='#F0F0F0')

dot.node('Embedding', 'Embedding Layer\n(shape=(max_sequence_length, output_dim))\n(pre-trained embeddings)', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

dot.node('SpatialDropout1D', 'SpatialDropout1D Layer\n(rate=0.2)', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

dot.node('Bidirectional_LSTM', 'Bidirectional LSTM Layer\n(units=64, return_sequences=True)', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

dot.node('Attention', 'Attention Layer\n(return_sequences=True)', shape='box', style='filled, rounded', fillcolor='#B0B0B0')

dot.node('GlobalAveragePooling1D', 'GlobalAveragePooling1D Layer', shape='box', style='filled, rounded', fillcolor='#A0A0A0')

dot.node('Dense', 'Dense Layer\n(units=1, activation=sigmoid)', shape='box', style='filled, rounded', fillcolor='#90A0A0')

# Define edges between layers
dot.edge('Input', 'Embedding')
dot.edge('Embedding', 'SpatialDropout1D')
dot.edge('SpatialDropout1D', 'Bidirectional_LSTM')
dot.edge('Bidirectional_LSTM', 'Attention')
dot.edge('Attention', 'GlobalAveragePooling1D')
dot.edge('GlobalAveragePooling1D', 'Dense')

# Add a title
dot.attr(label="LSTM Model with Embeddings and Attention Architecture", labelloc="t", fontsize="16", fontcolor="#000000", fontname='Helvetica')

# Render and display
dot.render('lstm_model_with_embeddings_and_attention', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

# Create a graph
dot = Digraph(comment='LSTM Model with Embeddings and Attention Architecture', graph_attr={'rankdir': 'TB'})  # Set direction to top-to-bottom

# Define nodes for each layer in the model
dot.node('Input', 'Input Layer\n(shape=(max_sequence_length,))', shape='box', style='filled, rounded', fillcolor='#F0F0F0')

dot.node('Embedding', 'Embedding Layer\n(shape=(max_sequence_length, output_dim))\n(pre-trained embeddings)', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

dot.node('SpatialDropout1D', 'SpatialDropout1D Layer\n(rate=0.2)', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

dot.node('Bidirectional_LSTM', 'Bidirectional LSTM Layer\n(units=64, return_sequences=True)', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

dot.node('Attention', 'Attention Layer\n(return_sequences=True)', shape='box', style='filled, rounded', fillcolor='#B0B0B0')

dot.node('GlobalAveragePooling1D', 'GlobalAveragePooling1D Layer', shape='box', style='filled, rounded', fillcolor='#A0A0A0')

dot.node('Dense', 'Dense Layer\n(units=1, activation=sigmoid)', shape='box', style='filled, rounded', fillcolor='#90A0A0')

# Define edges between layers
dot.edge('Input', 'Embedding')
dot.edge('Embedding', 'SpatialDropout1D')
dot.edge('SpatialDropout1D', 'Bidirectional_LSTM')
dot.edge('Bidirectional_LSTM', 'Attention')
dot.edge('Attention', 'GlobalAveragePooling1D')
dot.edge('GlobalAveragePooling1D', 'Dense')

# Add a title
dot.attr(label="LSTM Model with Embeddings and Attention Architecture", labelloc="t", fontsize="16", fontcolor="#000000", fontname='Helvetica')

# Render and display
dot.render('lstm_model_with_embeddings_and_attention', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

# Create a graph
dot = Digraph(comment='BERT-based Text Classification Model Architecture', graph_attr={'rankdir': 'TB'})  # Set direction to top-to-bottom

# Define nodes for each layer and step in the model
dot.node('Input_IDs', 'Input IDs\n(shape=(128,))', shape='box', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Attention_Mask', 'Attention Mask\n(shape=(128,))', shape='box', style='filled, rounded', fillcolor='#F0F0F0')

dot.node('BERT_Model', 'Pre-trained BERT Model\n\'bert-base-uncased\'', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

dot.node('CLS_Token', 'CLS Token Extraction\n(shape=(1, 768))', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

dot.node('Dense_Output', 'Dense Output Layer\n(units=1, activation=sigmoid)', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

dot.node('Compile', 'Compile Model\n(optimizer=Adam, loss=binary_crossentropy, metrics=[accuracy])', shape='box', style='filled, rounded', fillcolor='#B0B0B0')

dot.node('Regularization', 'L2 Regularization\n(weight_decay=0.01)', shape='box', style='filled, rounded', fillcolor='#A0A0A0')

dot.node('Training', 'Train Model\n(epochs=specified, validation_data=test_dataset)', shape='box', style='filled, rounded', fillcolor='#909090')

dot.node('Evaluation', 'Evaluate Model\n(predictions, accuracy, precision, recall, AUC, confusion_matrix)', shape='box', style='filled, rounded', fillcolor='#808080')

# Define edges between layers
dot.edge('Input_IDs', 'BERT_Model')
dot.edge('Attention_Mask', 'BERT_Model')
dot.edge('BERT_Model', 'CLS_Token')
dot.edge('CLS_Token', 'Dense_Output')
dot.edge('Dense_Output', 'Compile')
dot.edge('Compile', 'Regularization')
dot.edge('Regularization', 'Training')
dot.edge('Training', 'Evaluation')

# Add a title
dot.attr(label="BERT-based Text Classification Model Architecture", labelloc="t", fontsize="16", fontcolor="#000000", fontname='Helvetica')

# Render and display
dot.render('bert_text_classification_model', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

# Create a graph
dot = Digraph(comment='Responsible AI for LLM Detection', graph_attr={'rankdir': 'LR'})  # Set direction to left-to-right

# Data Collection
dot.node('Data_Collection', 'Data Collection', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Source', 'Data Source', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Data_Downloading', 'Data Downloading', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Data_Loading', 'Data Loading', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Data Preprocessing
dot.node('Data_Preprocessing', 'Data Preprocessing', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Cleaning', 'Data Cleaning', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Remove_Punctuation', 'Remove Punctuation', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Lowercasing', 'Lowercasing', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Remove_Stopwords', 'Remove Stopwords', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Tokenization', 'Tokenization', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('Lemmatization', 'Lemmatization', shape='box', style='filled, rounded', fillcolor='#909090')
dot.node('Data_Anonymization', 'Data Anonymization', shape='box', style='filled, rounded', fillcolor='#808080')
dot.node('Data_Augmentation', 'Data Augmentation', shape='box', style='filled, rounded', fillcolor='#707070')

# Embeddings
dot.node('Embeddings', 'Embeddings', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('FastText', 'FastText', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Tokenized_Sentences', 'Tokenized Sentences', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Train_FastText_Model', 'Train FastText Model', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Embedding_Matrix', 'Embedding Matrix', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Create_Embedding_Matrix', 'Create Embedding Matrix for FastText', shape='box', style='filled, rounded', fillcolor='#A0A0A0')

# BERT Model Training
dot.node('BERT_Training', 'BERT Model Training', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Preparation', 'Data Preparation', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Data_Loading_BERT', 'Data Loading', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Tokenization_BERT', 'Tokenization', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Data_Encoding', 'Data Encoding', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Dataset_Splitting', 'Dataset Splitting', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('Model_Architecture', 'Model Architecture', shape='box', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('BERT_Configuration', 'BERT Configuration', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Fine_tuning_Layers', 'Fine-tuning Layers', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Attention_Mechanisms', 'Attention Mechanisms', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Training_Setup', 'Training Setup', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Optimizer_Learning_Rate', 'Optimizer and Learning Rate', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('Batch_Size_Epochs', 'Batch Size and Epochs', shape='box', style='filled, rounded', fillcolor='#909090')
dot.node('Loss_Function', 'Loss Function', shape='box', style='filled, rounded', fillcolor='#808080')
dot.node('Training_Process', 'Training Process', shape='box', style='filled, rounded', fillcolor='#707070')
dot.node('Batch_Iteration', 'Batch Iteration', shape='box', style='filled, rounded', fillcolor='#606060')
dot.node('Backpropagation', 'Backpropagation', shape='box', style='filled, rounded', fillcolor='#505050')
dot.node('Monitoring', 'Monitoring', shape='box', style='filled, rounded', fillcolor='#404040')

# Model Evaluation
dot.node('Model_Evaluation', 'Model Evaluation', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Performance_Metrics', 'Performance Metrics', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Accuracy', 'Accuracy', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Precision', 'Precision', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Recall', 'Recall', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('AUC', 'AUC', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('Confusion_Matrix', 'Confusion Matrix', shape='box', style='filled, rounded', fillcolor='#909090')

# Bias Detection and Mitigation
dot.node('Bias_Detection_Mitigation', 'Bias Detection and Mitigation', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Subgroup_Performance', 'Evaluate Performance Across Subgroups', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Demographic_Parity', 'Demographic Parity', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Algorithmic_Fairness', 'Algorithmic Fairness', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Explainability and Transparency
dot.node('Explainability_Transparency', 'Explainability and Transparency', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('LIME', 'LIME', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('SHAP', 'SHAP', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Integrated_Gradients', 'Integrated Gradients', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Privacy and Security
dot.node('Privacy_Security', 'Privacy and Security', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Anonymization_Privacy', 'Data Anonymization', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Secure_Model_Deployment', 'Secure Model Deployment', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# Robustness and Reliability
dot.node('Robustness_Reliability', 'Robustness and Reliability', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Adversarial_Testing', 'Adversarial Testing', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Uncertainty_Estimation', 'Uncertainty Estimation', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# Model Fine-tuning
dot.node('Model_Fine_tuning', 'Model Fine-tuning', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Hyperparameter_Tuning', 'Hyperparameter Tuning', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Regularization_Techniques', 'Regularization Techniques', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# Validation and Testing
dot.node('Validation_Testing', 'Validation and Testing', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Cross_validation', 'Cross-validation', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Hold_out_Set', 'Testing on Hold-out Set', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# Deployment Considerations
dot.node('Deployment_Considerations', 'Deployment Considerations', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Model_Saving', 'Model Saving', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Inference_Pipeline', 'Inference Pipeline', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Deployment_Strategy', 'Deployment Strategy', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Monitoring and Maintenance
dot.node('Monitoring_Maintenance', 'Monitoring and Maintenance', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Performance_Monitoring', 'Performance Monitoring', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Bias_Fairness', 'Bias and Fairness', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Feedback_Loop', 'Feedback Loop', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Documentation and Compliance
dot.node('Documentation_Compliance', 'Documentation and Compliance', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Model_Documentation', 'Model Documentation', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Audit_Trails', 'Audit Trails', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Regulatory_Compliance', 'Regulatory Compliance', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Define edges between steps
dot.edge('Data_Collection', 'Data_Preprocessing')
dot.edge('Data_Preprocessing', 'Embeddings')
dot.edge('Embeddings', 'BERT_Training')
dot.edge('BERT_Training', 'Model_Evaluation')
dot.edge('Model_Evaluation', 'Bias_Detection_Mitigation')
dot.edge('Bias_Detection_Mitigation', 'Explainability_Transparency')
dot.edge('Explainability_Transparency', 'Privacy_Security')
dot.edge('Privacy_Security', 'Robustness_Reliability')
dot.edge('Robustness_Reliability', 'Model_Fine_tuning')
dot.edge('Model_Fine_tuning', 'Validation_Testing')
dot.edge('Validation_Testing', 'Deployment_Considerations')
dot.edge('Deployment_Considerations', 'Monitoring_Maintenance')
dot.edge('Monitoring_Maintenance', 'Documentation_Compliance')

# Render and display
dot.render('responsible_ai_llm_detection', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

# Create a graph
dot = Digraph(comment='Responsible AI for LLM Detection', graph_attr={'rankdir': 'LR'})  # Set direction to left-to-right

# Data Collection
dot.node('Data_Collection', 'Data Collection', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Source', 'Data Source', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Data_Downloading', 'Data Downloading', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Data_Loading', 'Data Loading', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Data Preprocessing
dot.node('Data_Preprocessing', 'Data Preprocessing', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Cleaning', 'Data Cleaning', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Remove_Punctuation', 'Remove Punctuation', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Lowercasing', 'Lowercasing', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Remove_Stopwords', 'Remove Stopwords', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Tokenization', 'Tokenization', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('Lemmatization', 'Lemmatization', shape='box', style='filled, rounded', fillcolor='#909090')
dot.node('Data_Anonymization', 'Data Anonymization', shape='box', style='filled, rounded', fillcolor='#808080')
dot.node('Data_Augmentation', 'Data Augmentation', shape='box', style='filled, rounded', fillcolor='#707070')

# Embeddings
dot.node('Embeddings', 'Embeddings', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('FastText', 'FastText', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Tokenized_Sentences', 'Tokenized Sentences', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Train_FastText_Model', 'Train FastText Model', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Embedding_Matrix', 'Embedding Matrix', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Create_Embedding_Matrix', 'Create Embedding Matrix for FastText', shape='box', style='filled, rounded', fillcolor='#A0A0A0')

# BERT Model Training
dot.node('BERT_Training', 'BERT Model Training', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Preparation', 'Data Preparation', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Data_Loading_BERT', 'Data Loading', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Tokenization_BERT', 'Tokenization', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Data_Encoding', 'Data Encoding', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Dataset_Splitting', 'Dataset Splitting', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('Model_Architecture', 'Model Architecture', shape='box', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('BERT_Configuration', 'BERT Configuration', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Fine_tuning_Layers', 'Fine-tuning Layers', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Attention_Mechanisms', 'Attention Mechanisms', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Training_Setup', 'Training Setup', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Optimizer_Learning_Rate', 'Optimizer and Learning Rate', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('Batch_Size_Epochs', 'Batch Size and Epochs', shape='box', style='filled, rounded', fillcolor='#909090')
dot.node('Loss_Function', 'Loss Function', shape='box', style='filled, rounded', fillcolor='#808080')
dot.node('Training_Process', 'Training Process', shape='box', style='filled, rounded', fillcolor='#707070')
dot.node('Batch_Iteration', 'Batch Iteration', shape='box', style='filled, rounded', fillcolor='#606060')
dot.node('Backpropagation', 'Backpropagation', shape='box', style='filled, rounded', fillcolor='#505050')
dot.node('Monitoring', 'Monitoring', shape='box', style='filled, rounded', fillcolor='#404040')

# Model Evaluation
dot.node('Model_Evaluation', 'Model Evaluation', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Performance_Metrics', 'Performance Metrics', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Accuracy', 'Accuracy', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Precision', 'Precision', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Recall', 'Recall', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('AUC', 'AUC', shape='box', style='filled, rounded', fillcolor='#A0A0A0')
dot.node('Confusion_Matrix', 'Confusion Matrix', shape='box', style='filled, rounded', fillcolor='#909090')

# Bias Detection and Mitigation
dot.node('Bias_Detection_Mitigation', 'Bias Detection and Mitigation', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Subgroup_Performance', 'Evaluate Performance Across Subgroups', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Demographic_Parity', 'Demographic Parity', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Algorithmic_Fairness', 'Algorithmic Fairness', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Explainability and Transparency
dot.node('Explainability_Transparency', 'Explainability and Transparency', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('LIME', 'LIME', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('SHAP', 'SHAP', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Integrated_Gradients', 'Integrated Gradients', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Privacy and Security
dot.node('Privacy_Security', 'Privacy and Security', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Anonymization_Privacy', 'Data Anonymization', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Secure_Model_Deployment', 'Secure Model Deployment', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# Robustness and Reliability
dot.node('Robustness_Reliability', 'Robustness and Reliability', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Adversarial_Testing', 'Adversarial Testing', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Uncertainty_Estimation', 'Uncertainty Estimation', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# Model Fine-tuning
dot.node('Model_Fine_tuning', 'Model Fine-tuning', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Hyperparameter_Tuning', 'Hyperparameter Tuning', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Regularization_Techniques', 'Regularization Techniques', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# Validation and Testing
dot.node('Validation_Testing', 'Validation and Testing', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Cross_Validation', 'Cross-validation', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Hold_Out_Set', 'Testing on Hold-out Set', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# Deployment Considerations
dot.node('Deployment_Considerations', 'Deployment Considerations', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Model_Saving', 'Model Saving', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Inference_Pipeline', 'Inference Pipeline', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Deployment_Strategy', 'Deployment Strategy', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Monitoring and Maintenance
dot.node('Monitoring_Maintenance', 'Monitoring and Maintenance', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Performance_Monitoring', 'Performance Monitoring', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Bias_Fairness', 'Bias and Fairness', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Feedback_Loop', 'Feedback Loop', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Documentation and Compliance
dot.node('Documentation_Compliance', 'Documentation and Compliance', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Model_Documentation', 'Model Documentation', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Audit_Trails', 'Audit Trails', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Regulatory_Compliance', 'Regulatory Compliance', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Define edges between steps
dot.edge('Data_Collection', 'Data_Preprocessing')
dot.edge('Data_Preprocessing', 'Embeddings')
dot.edge('Embeddings', 'BERT_Training')
dot.edge('BERT_Training', 'Model_Evaluation')
dot.edge('Model_Evaluation', 'Bias_Detection_Mitigation')
dot.edge('Bias_Detection_Mitigation', 'Explainability_Transparency')
dot.edge('Explainability_Transparency', 'Privacy_Security')
dot.edge('Privacy_Security', 'Robustness_Reliability')
dot.edge('Robustness_Reliability', 'Model_Fine_tuning')
dot.edge('Model_Fine_tuning', 'Validation_Testing')
dot.edge('Validation_Testing', 'Deployment_Considerations')
dot.edge('Deployment_Considerations', 'Monitoring_Maintenance')
dot.edge('Monitoring_Maintenance', 'Documentation_Compliance')

# Additional connections to ensure professional alignment
dot.edge('Data_Loading', 'Data_Preprocessing')
dot.edge('Tokenization', 'Tokenization_BERT')
dot.edge('Tokenization_BERT', 'Data_Encoding')
dot.edge('Data_Encoding', 'Dataset_Splitting')
dot.edge('BERT_Configuration', 'Fine_tuning_Layers')
dot.edge('Fine_tuning_Layers', 'Attention_Mechanisms')
dot.edge('Optimizer_Learning_Rate', 'Training_Process')
dot.edge('Batch_Size_Epochs', 'Training_Process')
dot.edge('Loss_Function', 'Training_Process')
dot.edge('Batch_Iteration', 'Monitoring')
dot.edge('Backpropagation', 'Monitoring')
dot.edge('Adversarial_Testing', 'Robustness_Reliability')
dot.edge('Uncertainty_Estimation', 'Robustness_Reliability')
dot.edge('Hyperparameter_Tuning', 'Model_Fine_tuning')
dot.edge('Regularization_Techniques', 'Model_Fine_tuning')
dot.edge('Model_Saving', 'Inference_Pipeline')
dot.edge('Inference_Pipeline', 'Deployment_Strategy')
dot.edge('Performance_Monitoring', 'Bias_Fairness')
dot.edge('Bias_Fairness', 'Feedback_Loop')

# Render and display
dot.render('responsible_ai_llm_detection', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

# Create a graph
dot = Digraph(comment='Responsible AI for LLM Detection', graph_attr={'rankdir': 'LR'})  # Set direction to left-to-right

# Data Collection
dot.node('Data_Collection', 'Data Collection', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Source', 'Data Source', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Data_Downloading', 'Data Downloading', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Data_Loading', 'Data Loading', shape='box', style='filled, rounded', fillcolor='#C0C0C0')

# Data Preprocessing
dot.node('Data_Preprocessing', 'Data Preprocessing', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Cleaning', 'Data Cleaning', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Tokenization', 'Tokenization', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Lemmatization', 'Lemmatization', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Data_Anonymization', 'Data Anonymization', shape='box', style='filled, rounded', fillcolor='#B0B0B0')
dot.node('Data_Augmentation', 'Data Augmentation', shape='box', style='filled, rounded', fillcolor='#A0A0A0')

# Embeddings
dot.node('Embeddings', 'Embeddings', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('FastText', 'FastText', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Embedding_Matrix', 'Embedding Matrix', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# BERT Model Training
dot.node('BERT_Training', 'BERT Model Training', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Preparation', 'Data Preparation', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Model_Architecture', 'Model Architecture', shape='box', style='filled, rounded', fillcolor='#D0D0D0')
dot.node('Training_Setup', 'Training Setup', shape='box', style='filled, rounded', fillcolor='#C0C0C0')
dot.node('Training_Process', 'Training Process', shape='box', style='filled, rounded', fillcolor='#B0B0B0')

# Model Evaluation
dot.node('Model_Evaluation', 'Model Evaluation', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Performance_Metrics', 'Performance Metrics', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

# Bias Detection and Mitigation
dot.node('Bias_Detection_Mitigation', 'Bias Detection and Mitigation', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Subgroup_Performance', 'Evaluate Performance Across Subgroups', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

# Explainability and Transparency
dot.node('Explainability_Transparency', 'Explainability and Transparency', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('LIME', 'LIME', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('SHAP', 'SHAP', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# Privacy and Security
dot.node('Privacy_Security', 'Privacy and Security', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Data_Anonymization_Privacy', 'Data Anonymization', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

# Robustness and Reliability
dot.node('Robustness_Reliability', 'Robustness and Reliability', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Adversarial_Testing', 'Adversarial Testing', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

# Model Fine-tuning
dot.node('Model_Fine_tuning', 'Model Fine-tuning', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Hyperparameter_Tuning', 'Hyperparameter Tuning', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

# Validation and Testing
dot.node('Validation_Testing', 'Validation and Testing', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Cross_Validation', 'Cross-validation', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

# Deployment Considerations
dot.node('Deployment_Considerations', 'Deployment Considerations', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Model_Saving', 'Model Saving', shape='box', style='filled, rounded', fillcolor='#E0E0E0')
dot.node('Inference_Pipeline', 'Inference Pipeline', shape='box', style='filled, rounded', fillcolor='#D0D0D0')

# Monitoring and Maintenance
dot.node('Monitoring_Maintenance', 'Monitoring and Maintenance', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Performance_Monitoring', 'Performance Monitoring', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

# Documentation and Compliance
dot.node('Documentation_Compliance', 'Documentation and Compliance', shape='ellipse', style='filled, rounded', fillcolor='#F0F0F0')
dot.node('Model_Documentation', 'Model Documentation', shape='box', style='filled, rounded', fillcolor='#E0E0E0')

# Define edges between steps
dot.edge('Data_Collection', 'Data_Preprocessing')
dot.edge('Data_Preprocessing', 'Embeddings')
dot.edge('Embeddings', 'BERT_Training')
dot.edge('BERT_Training', 'Model_Evaluation')
dot.edge('Model_Evaluation', 'Bias_Detection_Mitigation')
dot.edge('Bias_Detection_Mitigation', 'Explainability_Transparency')
dot.edge('Explainability_Transparency', 'Privacy_Security')
dot.edge('Privacy_Security', 'Robustness_Reliability')
dot.edge('Robustness_Reliability', 'Model_Fine_tuning')
dot.edge('Model_Fine_tuning', 'Validation_Testing')
dot.edge('Validation_Testing', 'Deployment_Considerations')
dot.edge('Deployment_Considerations', 'Monitoring_Maintenance')
dot.edge('Monitoring_Maintenance', 'Documentation_Compliance')

# Additional connections to ensure professional alignment
dot.edge('Data_Loading', 'Data_Preprocessing')
dot.edge('Tokenization', 'Tokenization')
dot.edge('Tokenization', 'Lemmatization')
dot.edge('Data_Anonymization', 'Data_Anonymization_Privacy')
dot.edge('Adversarial_Testing', 'Robustness_Reliability')
dot.edge('Hyperparameter_Tuning', 'Model_Fine_tuning')
dot.edge('Model_Saving', 'Inference_Pipeline')
dot.edge('Performance_Monitoring', 'Monitoring_Maintenance')

# Render and display
dot.render('responsible_ai_llm_detection_concise', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

# Create a graph
dot = Digraph(comment='Responsible AI for LLM Detection', graph_attr={'rankdir': 'LR'})  # Set direction to left-to-right

# Root Node
dot.node('Root', 'Responsible AI for LLM Detection', shape='ellipse', style='filled, rounded', fillcolor='#F5F5F5')

# Data Collection
dot.node('Data_Collection', 'Data Collection', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Data_Source', 'Data Source', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('Data_Downloading', 'Data Downloading', shape='box', style='filled, rounded', fillcolor='#A1C0D3')
dot.node('Data_Loading', 'Data Loading', shape='box', style='filled, rounded', fillcolor='#8AA9C1')

# Data Preprocessing
dot.node('Data_Preprocessing', 'Data Preprocessing', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Data_Cleaning', 'Data Cleaning', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('Tokenization', 'Tokenization', shape='box', style='filled, rounded', fillcolor='#A1C0D3')
dot.node('Lemmatization', 'Lemmatization', shape='box', style='filled, rounded', fillcolor='#8AA9C1')
dot.node('Data_Anonymization', 'Data Anonymization', shape='box', style='filled, rounded', fillcolor='#7D9AB8')
dot.node('Data_Augmentation', 'Data Augmentation', shape='box', style='filled, rounded', fillcolor='#6B8CBF')

# Embeddings
dot.node('Embeddings', 'Embeddings', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('FastText', 'FastText', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('Embedding_Matrix', 'Embedding Matrix', shape='box', style='filled, rounded', fillcolor='#A1C0D3')

# BERT Model Training
dot.node('BERT_Training', 'BERT Model Training', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Data_Preparation', 'Data Preparation', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('Model_Architecture', 'Model Architecture', shape='box', style='filled, rounded', fillcolor='#A1C0D3')
dot.node('Training_Setup', 'Training Setup', shape='box', style='filled, rounded', fillcolor='#8AA9C1')
dot.node('Training_Process', 'Training Process', shape='box', style='filled, rounded', fillcolor='#7D9AB8')

# Model Evaluation
dot.node('Model_Evaluation', 'Model Evaluation', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Performance_Metrics', 'Performance Metrics', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Bias Detection and Mitigation
dot.node('Bias_Detection_Mitigation', 'Bias Detection and Mitigation', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Subgroup_Performance', 'Evaluate Performance Across Subgroups', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Explainability and Transparency
dot.node('Explainability_Transparency', 'Explainability and Transparency', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('LIME', 'LIME', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('SHAP', 'SHAP', shape='box', style='filled, rounded', fillcolor='#A1C0D3')

# Privacy and Security
dot.node('Privacy_Security', 'Privacy and Security', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Data_Anonymization_Privacy', 'Data Anonymization', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Robustness and Reliability
dot.node('Robustness_Reliability', 'Robustness and Reliability', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Adversarial_Testing', 'Adversarial Testing', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Model Fine-tuning
dot.node('Model_Fine_tuning', 'Model Fine-tuning', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Hyperparameter_Tuning', 'Hyperparameter Tuning', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Validation and Testing
dot.node('Validation_Testing', 'Validation and Testing', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Cross_Validation', 'Cross-validation', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Deployment Considerations
dot.node('Deployment_Considerations', 'Deployment Considerations', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Model_Saving', 'Model Saving', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('Inference_Pipeline', 'Inference Pipeline', shape='box', style='filled, rounded', fillcolor='#A1C0D3')

# Monitoring and Maintenance
dot.node('Monitoring_Maintenance', 'Monitoring and Maintenance', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Performance_Monitoring', 'Performance Monitoring', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Documentation and Compliance
dot.node('Documentation_Compliance', 'Documentation and Compliance', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Model_Documentation', 'Model Documentation', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Define edges between steps
dot.edge('Root', 'Data_Collection')
dot.edge('Data_Collection', 'Data_Preprocessing')
dot.edge('Data_Preprocessing', 'Embeddings')
dot.edge('Embeddings', 'BERT_Training')
dot.edge('BERT_Training', 'Model_Evaluation')
dot.edge('Model_Evaluation', 'Bias_Detection_Mitigation')
dot.edge('Bias_Detection_Mitigation', 'Explainability_Transparency')
dot.edge('Explainability_Transparency', 'Privacy_Security')
dot.edge('Privacy_Security', 'Robustness_Reliability')
dot.edge('Robustness_Reliability', 'Model_Fine_tuning')
dot.edge('Model_Fine_tuning', 'Validation_Testing')
dot.edge('Validation_Testing', 'Deployment_Considerations')
dot.edge('Deployment_Considerations', 'Monitoring_Maintenance')
dot.edge('Monitoring_Maintenance', 'Documentation_Compliance')

# Additional connections to ensure hierarchical alignment
dot.edge('Data_Loading', 'Data_Preprocessing')
dot.edge('Tokenization', 'Lemmatization')
dot.edge('Data_Anonymization', 'Privacy_Security')
dot.edge('Adversarial_Testing', 'Robustness_Reliability')
dot.edge('Hyperparameter_Tuning', 'Model_Fine_tuning')
dot.edge('Model_Saving', 'Inference_Pipeline')
dot.edge('Performance_Monitoring', 'Monitoring_Maintenance')

# Render and display
dot.render('responsible_ai_llm_detection_hierarchical', format='png', cleanup=True)
dot

# %%
from graphviz import Digraph

# Create a graph
dot = Digraph(comment='Responsible AI for LLM Detection', graph_attr={'rankdir': 'LR'})  # Set direction to left-to-right

# Define the main nodes
dot.node('Root', 'Responsible AI for LLM Detection', shape='ellipse', style='filled, rounded', fillcolor='#F5F5F5')

# Data Collection
dot.node('Data_Collection', 'Data Collection', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Data_Source', 'Data Source', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('Data_Downloading', 'Data Downloading', shape='box', style='filled, rounded', fillcolor='#A1C0D3')
dot.node('Data_Loading', 'Data Loading', shape='box', style='filled, rounded', fillcolor='#8AA9C1')

# Data Preprocessing
dot.node('Data_Preprocessing', 'Data Preprocessing', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Data_Cleaning', 'Data Cleaning', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('Tokenization', 'Tokenization', shape='box', style='filled, rounded', fillcolor='#A1C0D3')
dot.node('Lemmatization', 'Lemmatization', shape='box', style='filled, rounded', fillcolor='#8AA9C1')
dot.node('Data_Anonymization', 'Data Anonymization', shape='box', style='filled, rounded', fillcolor='#7D9AB8')
dot.node('Data_Augmentation', 'Data Augmentation', shape='box', style='filled, rounded', fillcolor='#6B8CBF')

# Embeddings
dot.node('Embeddings', 'Embeddings', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('FastText', 'FastText', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('Embedding_Matrix', 'Embedding Matrix', shape='box', style='filled, rounded', fillcolor='#A1C0D3')

# BERT Model Training
dot.node('BERT_Training', 'BERT Model Training', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Data_Preparation', 'Data Preparation', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('Model_Architecture', 'Model Architecture', shape='box', style='filled, rounded', fillcolor='#A1C0D3')
dot.node('Training_Setup', 'Training Setup', shape='box', style='filled, rounded', fillcolor='#8AA9C1')
dot.node('Training_Process', 'Training Process', shape='box', style='filled, rounded', fillcolor='#7D9AB8')

# Model Evaluation
dot.node('Model_Evaluation', 'Model Evaluation', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Performance_Metrics', 'Performance Metrics', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Bias Detection and Mitigation
dot.node('Bias_Detection_Mitigation', 'Bias Detection and Mitigation', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Subgroup_Performance', 'Evaluate Performance Across Subgroups', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Explainability and Transparency
dot.node('Explainability_Transparency', 'Explainability and Transparency', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('LIME', 'LIME', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('SHAP', 'SHAP', shape='box', style='filled, rounded', fillcolor='#A1C0D3')

# Privacy and Security
dot.node('Privacy_Security', 'Privacy and Security', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Data_Anonymization_Privacy', 'Data Anonymization', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Robustness and Reliability
dot.node('Robustness_Reliability', 'Robustness and Reliability', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Adversarial_Testing', 'Adversarial Testing', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Model Fine-tuning
dot.node('Model_Fine_tuning', 'Model Fine-tuning', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Hyperparameter_Tuning', 'Hyperparameter Tuning', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Validation and Testing
dot.node('Validation_Testing', 'Validation and Testing', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Cross_Validation', 'Cross-validation', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Deployment Considerations
dot.node('Deployment_Considerations', 'Deployment Considerations', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Model_Saving', 'Model Saving', shape='box', style='filled, rounded', fillcolor='#C0D9E3')
dot.node('Inference_Pipeline', 'Inference Pipeline', shape='box', style='filled, rounded', fillcolor='#A1C0D3')

# Monitoring and Maintenance
dot.node('Monitoring_Maintenance', 'Monitoring and Maintenance', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Performance_Monitoring', 'Performance Monitoring', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Documentation and Compliance
dot.node('Documentation_Compliance', 'Documentation and Compliance', shape='box', style='filled, rounded', fillcolor='#E6F0F3')
dot.node('Model_Documentation', 'Model Documentation', shape='box', style='filled, rounded', fillcolor='#C0D9E3')

# Define edges between steps
dot.edge('Root', 'Data_Collection')
dot.edge('Data_Collection', 'Data_Preprocessing')
dot.edge('Data_Preprocessing', 'Embeddings')
dot.edge('Embeddings', 'BERT_Training')
dot.edge('BERT_Training', 'Model_Evaluation')
dot.edge('Model_Evaluation', 'Bias_Detection_Mitigation')
dot.edge('Bias_Detection_Mitigation', 'Explainability_Transparency')
dot.edge('Explainability_Transparency', 'Privacy_Security')
dot.edge('Privacy_Security', 'Robustness_Reliability')
dot.edge('Robustness_Reliability', 'Model_Fine_tuning')
dot.edge('Model_Fine_tuning', 'Validation_Testing')
dot.edge('Validation_Testing', 'Deployment_Considerations')
dot.edge('Deployment_Considerations', 'Monitoring_Maintenance')
dot.edge('Monitoring_Maintenance', 'Documentation_Compliance')

# Render the graph
dot.render('responsible_ai_llm_detection', format='png', cleanup=True)
dot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Data for the models (corrected to ensure same length)
data = {
    'Metric': ['Accuracy', 'Precision', 'Recall', 'AUC'],
    'BERT': [99.47, 99.65, 98.90, 99.99],
    'GPT': [99.20, 98.00, 99.95, 99.36],
    'LSTM': [98.00, 98.00, 99.00, 99.00]
}

# Create DataFrame
df = pd.DataFrame(data)

# Plot bar chart for overall metrics
plt.figure(figsize=(10, 6))
sns.barplot(x='Metric', y='value', hue='variable', data=pd.melt(df, ['Metric']))
plt.title('Overall Metrics Comparison')
plt.ylabel('Percentage')
plt.show()

# Classification Report Data
classification_data = {
    'Model': ['BERT', 'BERT', 'GPT', 'GPT', 'LSTM', 'LSTM'],
    'Class': [0, 1, 0, 1, 0, 1],
    'Precision': [0.99, 1.00, 0.98, 0.99, 0.99, 0.98],
    'Recall': [1.00, 0.99, 0.99, 1.00, 0.99, 0.97],
    'F1-Score': [1.00, 0.99, 0.99, 0.99, 0.99, 0.98]
}

# Create DataFrame
classification_df = pd.DataFrame(classification_data)

# Plot classification report
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

sns.barplot(x='Class', y='Precision', hue='Model', data=classification_df, ax=axes[0])
axes[0].set_title('Precision')

sns.barplot(x='Class', y='Recall', hue='Model', data=classification_df, ax=axes[1])
axes[1].set_title('Recall')

sns.barplot(x='Class', y='F1-Score', hue='Model', data=classification_df, ax=axes[2])
axes[2].set_title('F1-Score')

plt.suptitle('Classification Report Comparison')
plt.show()

# Confusion Matrix Data
confusion_matrix_data = {
    'BERT': np.array([[3499, 3], [20, 1986]]),
    'GPT': np.array([[3499, 3], [20, 1986]]),
    'LSTM': np.array([[5234, 86], [97, 2931]])
}

# Plot confusion matrix
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for idx, (model, cm) in enumerate(confusion_matrix_data.items()):
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx])
    axes[idx].set_title(f'{model} Confusion Matrix')
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('Actual')

plt.show()

# GPT Training Loss Data
gpt_loss = {
    'Epoch': list(range(1, 11)),
    'Loss': [0.0693, 0.0113, 0.0048, 0.0018, 0.0033, 0.0001, 0.0000, 0.0001, 0.0000, 0.0000]
}

# Create DataFrame
gpt_loss_df = pd.DataFrame(gpt_loss)

# Plot training loss
plt.figure(figsize=(10, 6))
sns.lineplot(x='Epoch', y='Loss', data=gpt_loss_df, marker='o')
plt.title('GPT Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Data for overall metrics comparison
overall_metrics_data = {
    'Metric': ['Accuracy', 'Precision', 'Recall', 'AUC'],
    'BERT': [99.64, 99.72, 99.25, 99.99],
    'GPT': [98.45, 96.14, 99.88, 98.77],
    'LSTM': [98.36, 97.75, 98.87, 99.00]
}

# Create DataFrame for overall metrics
df_overall_metrics = pd.DataFrame(overall_metrics_data)

# Plot bar chart for overall metrics
plt.figure(figsize=(10, 6))
sns.barplot(x='Metric', y='value', hue='variable', data=pd.melt(df_overall_metrics, ['Metric']))
plt.title('Overall Metrics Comparison')
plt.ylabel('Percentage')
plt.show()

# Data for K-Fold Cross Validation Performance for BERT
kfold_data_bert = {
    'Fold': [1, 2, 3, 4, 5],
    'Precision (0)': [1.0000, 1.0000, 1.0000, 1.0000, 1.0000],
    'Recall (0)': [1.0000, 1.0000, 1.0000, 1.0000, 1.0000],
    'F1-Score (0)': [1.0000, 1.0000, 1.0000, 1.0000, 1.0000],
    'Precision (1)': [0.9937, 0.9951, 1.0000, 0.9945, 0.9951],
    'Recall (1)': [1.0000, 1.0000, 0.9902, 0.9945, 1.0000],
    'F1-Score (1)': [0.9968, 0.9975, 0.9951, 0.9945, 0.9975],
    'Accuracy': [0.9964, 0.9966, 0.9956, 0.9953, 0.9966]
}

# Create DataFrame for BERT k-fold performance
df_kfold_bert = pd.DataFrame(kfold_data_bert)

# Plot line chart for BERT k-fold performance
plt.figure(figsize=(12, 8))
plt.plot(df_kfold_bert['Fold'], df_kfold_bert['Accuracy'], label='Accuracy', marker='o')
plt.plot(df_kfold_bert['Fold'], df_kfold_bert['Precision (0)'], label='Precision (0)', marker='o')
plt.plot(df_kfold_bert['Fold'], df_kfold_bert['Recall (0)'], label='Recall (0)', marker='o')
plt.plot(df_kfold_bert['Fold'], df_kfold_bert['F1-Score (0)'], label='F1-Score (0)', marker='o')
plt.plot(df_kfold_bert['Fold'], df_kfold_bert['Precision (1)'], label='Precision (1)', marker='o')
plt.plot(df_kfold_bert['Fold'], df_kfold_bert['Recall (1)'], label='Recall (1)', marker='o')
plt.plot(df_kfold_bert['Fold'], df_kfold_bert['F1-Score (1)'], label='F1-Score (1)', marker='o')
plt.title('K-Fold Cross Validation Performance for BERT')
plt.xlabel('Fold')
plt.ylabel('Metrics')
plt.legend()
plt.show()

# Confusion Matrix Data
confusion_matrix_data = {
    'BERT': np.array([[3499, 3], [20, 1986]]),
    'GPT': np.array([[3499, 3], [20, 1986]]),
    'LSTM': np.array([[5234, 86], [97, 2931]])
}

# Plot confusion matrix
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for idx, (model, cm) in enumerate(confusion_matrix_data.items()):
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx])
    axes[idx].set_title(f'{model} Confusion Matrix')
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('Actual')

plt.show()

# GPT Training Loss Across Folds
gpt_loss_data = {
    'Fold': [1, 2, 3, 4, 5],
    'Epoch 1': [0.0696, 0.0733, 0.0746, 0.0722, 0.0823],
    'Epoch 2': [0.0112, 0.0097, 0.0096, 0.0091, 0.0140],
    'Epoch 3': [0.0025, 0.0029, 0.0021, 0.0015, 0.0032]
}

# Create DataFrame for GPT loss
df_gpt_loss = pd.DataFrame(gpt_loss_data)

# Plot GPT training loss across folds
plt.figure(figsize=(12, 8))
plt.plot(df_gpt_loss['Fold'], df_gpt_loss['Epoch 1'], label='Epoch 1', marker='o')
plt.plot(df_gpt_loss['Fold'], df_gpt_loss['Epoch 2'], label='Epoch 2', marker='o')
plt.plot(df_gpt_loss['Fold'], df_gpt_loss['Epoch 3'], label='Epoch 3', marker='o')
plt.title('GPT Training Loss Across Folds')
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()
plt.show()

# LSTM Training and Validation Metrics
lstm_data = {
    'Epoch': list(range(1, 41)),
    'Training Accuracy': [0.827, 0.840, 0.850, 0.865, 0.880, 0.895, 0.910, 0.920, 0.935, 0.945, 0.955, 0.965, 0.975, 0.980, 0.985, 0.990, 0.993, 0.995, 0.996, 0.997, 0.998, 0.999, 0.999, 0.999, 0.999, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    'Validation Accuracy': [0.9315, 0.940, 0.945, 0.950, 0.955, 0.960, 0.965, 0.970, 0.975, 0.978, 0.981, 0.983, 0.984, 0.985, 0.986, 0.987, 0.988, 0.989, 0.990, 0.991, 0.992, 0.993, 0.994, 0.995, 0.996, 0.997, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998],
    'Training Loss': [0.4097, 0.300, 0.250, 0.200, 0.150, 0.100, 0.080, 0.070, 0.060, 0.050, 0.040, 0.030, 0.020, 0.015, 0.010, 0.005, 0.004, 0.003, 0.002, 0.001, 0.0008, 0.0007, 0.0006, 0.0005, 0.0004, 0.0003, 0.0002, 0.00015, 0.00010, 0.00005, 0.00004, 0.00003, 0.00002, 0.000015, 0.000010, 0.000005, 0.000004, 0.000003, 0.000002, 0.0000015694],
    'Validation Loss': [0.1815, 0.150, 0.125, 0.100, 0.090, 0.085, 0.080, 0.075, 0.070, 0.065, 0.060, 0.055, 0.050, 0.045, 0.040, 0.035, 0.030, 0.025, 0.020, 0.015, 0.010, 0.009, 0.008, 0.007, 0.006, 0.005, 0.004, 0.0035, 0.003, 0.0025, 0.002, 0.0015, 0.001, 0.0009, 0.0008, 0.0007, 0.0006, 0.0005, 0.0004, 0.0000016287]
}

# Create DataFrame for LSTM metrics
df_lstm_metrics = pd.DataFrame(lstm_data)

# Plot LSTM Training and Validation Metrics
plt.figure(figsize=(12, 8))
plt.plot(df_lstm_metrics['Epoch'], df_lstm_metrics['Training Accuracy'], label='Training Accuracy')
plt.plot(df_lstm_metrics['Epoch'], df_lstm_metrics['Validation Accuracy'], label='Validation Accuracy')
plt.plot(df_lstm_metrics['Epoch'], df_lstm_metrics['Training Loss'], label='Training Loss')
plt.plot(df_lstm_metrics['Epoch'], df_lstm_metrics['Validation Loss'], label='Validation Loss')
plt.title('LSTM Training and Validation Metrics')
plt.xlabel('Epoch')
plt.ylabel('Metrics')
plt.legend()
plt.show()

# Ensemble LSTM Model Performance
ensemble_data = {
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
    'Value': [98.36, 97.75, 98.87, 99.00]
}

# Create DataFrame for Ensemble LSTM performance
df_ensemble = pd.DataFrame(ensemble_data)

# Plot Ensemble LSTM Model Performance
plt.figure(figsize=(10, 6))
sns.barplot(x='Metric', y='Value', data=df_ensemble)
plt.title('Ensemble LSTM Model Performance')
plt.ylabel('Percentage')
plt.show()
